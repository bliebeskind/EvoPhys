# %%
import numpy as np
import pandas as pd
from scipy.stats import norm
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
concRange = 1000
step = 1

# %% [markdown]
# ### Macroscopic binding constants

# %%
# Bulk

K1 = .01
K2 = .50

bb_oneSiteFunc = lambda x: (K1*x)/(1 + K1*x)
bb_twoSiteFunc = lambda x: (K1*x + 2*K1*K2*(x**2)) / (1 + K1*x + K1*K2*(x**2))

# %%
x_bar_2 = [bb_twoSiteFunc(i) for i in np.arange(concRange,step=step)]

# %%
plt.plot(x_bar_2)
plt.xscale("log")
plt.xlabel("Concentration")
plt.ylabel("Binding")

# %% [markdown]
# ### Microscopic binding constants

# %%
k1 = .01
k2 = .05

ss_twoSiteFunc = lambda x: ((k1 + k2)*x + 2*k1*k2*x**2) / (1 + (k1 + k2)*x + k1*k2*x**2)

# %%
x_bar_2ss = [ss_twoSiteFunc(i) for i in np.arange(concRange,step=step)]

# %%
plt.plot(x_bar_2ss)
plt.xscale("log")
plt.xlabel("Concentration")
plt.ylabel("Binding")

# %%
def wiener_proc(init=0,delta=.5,dt=.1,n=100):
    '''te,he,he'''
    out = []
    x = init
    for ind,i in enumerate(range(n)):
        x = x + norm.rvs(scale=delta**2*dt)
        out.append(x)
    return out

# %%
plt.plot()

length = 100
num_iters = 10

processes = []
for i in range(num_iters):
    plt.plot(wiener_proc())
